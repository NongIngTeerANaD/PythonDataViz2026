# %% [markdown]
# <a href="https://colab.research.google.com/github/NongIngTeerANaD/PythonDataViz2026/blob/main/Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = '/content/drive/MyDrive/Year 4/DataViz/Datasets'

# %%
covid_file_path = os.path.join(path,'confirmed-cases.csv')
print(covid_file_path)
# Out:
# /content/drive/MyDrive/Year 4/DataViz/Datasets/confirmed-cases.csv

# %%
a = path + '/confirmed-cases.csv'
print(a)
# Out:
# /content/drive/MyDrive/Year 4/DataViz/Datasets/confirmed-cases.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No. announce_date Notified date   sex   age nationality  \
# 0          1       12/1/20           NaN  หญิง  61.0       China
# 1          2       17/1/20           NaN  หญิง  74.0       China
# 2          3       22/1/20           NaN  หญิง  73.0    Thailand
# 3          4       22/1/20           NaN   ชาย  68.0       China
# 4          5       24/1/20           NaN  หญิง  66.0       China
# ...      ...           ...           ...   ...   ...         ...
# 12648  12649       20/1/21     19/1/2021   ชาย  42.0    Thailand
# 12649  12650       20/1/21     19/1/2021  หญิง  44.0    Thailand
# 12650  12651       20/1/21     19/1/2021  หญิง  52.0    Thailand
# 12651  12652       20/1/21     19/1/2021  หญิง  23.0    Thailand
# 12652  12653       20/1/21     19/1/2021  หญิง  29.0    Thailand
#
#       province_of_isolation province_of_onset district_of_onset  \
# 0             กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1             กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                    นครปฐม            นครปฐม             เมือง
# 3             กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4                   นนทบุรี     กรุงเทพมหานคร               NaN
# ...                     ...               ...               ...
# 12648           สมุทรปราการ     กรุงเทพมหานคร         ลาดกระบัง
# 12649                ชลบุรี            ชลบุรี          บางละมุง
# 12650                 ระยอง             ระยอง              แกลง
# 12651                 ระยอง             ระยอง         นิคมพัฒนา
# 12652                 ระยอง             ระยอง             เมือง
#
#                                                 risk
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                              ...
# 12648  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 12649                               State Quarantine
# 12650    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12652                                  Cluster ระยอง
#
# [12653 rows x 10 columns]

# %%
data_covid.head()
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 0    1       12/1/20           NaN  หญิง  61.0       China
# 1    2       17/1/20           NaN  หญิง  74.0       China
# 2    3       22/1/20           NaN  หญิง  73.0    Thailand
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 4    5       24/1/20           NaN  หญิง  66.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 0         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                นครปฐม            นครปฐม             เมือง
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4               นนทบุรี     กรุงเทพมหานคร               NaN
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  คนต่างชาติเดินทางมาจากต่างประเทศ

# %%
data_covid.shape
# Out:
# (12653, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648    กรุงเทพมหานคร
# 12649           ชลบุรี
# 12650            ระยอง
# 12651            ระยอง
# 12652            ระยอง
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset'][4]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']]
smaller_table
# Out:
#       announce_date province_of_onset  \
# 0           12/1/20     กรุงเทพมหานคร
# 1           17/1/20     กรุงเทพมหานคร
# 2           22/1/20            นครปฐม
# 3           22/1/20     กรุงเทพมหานคร
# 4           24/1/20     กรุงเทพมหานคร
# ...             ...               ...
# 12648       20/1/21     กรุงเทพมหานคร
# 12649       20/1/21            ชลบุรี
# 12650       20/1/21             ระยอง
# 12651       20/1/21             ระยอง
# 12652       20/1/21             ระยอง
#
#                                                 risk
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                              ...
# 12648  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 12649                               State Quarantine
# 12650    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12652                                  Cluster ระยอง
#
# [12653 rows x 3 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 1    2       17/1/20           NaN  หญิง  74.0       China
# 2    3       22/1/20           NaN  หญิง  73.0    Thailand
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 4    5       24/1/20           NaN  หญิง  66.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 1         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                นครปฐม            นครปฐม             เมือง
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4               นนทบุรี     กรุงเทพมหานคร               NaN
#
#                                risk
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  คนต่างชาติเดินทางมาจากต่างประเทศ

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#          No. announce_date Notified date   sex   age nationality  \
# 181      182       18/3/20     15/3/2020   ชาย  33.0    Thailand
# 463      464       22/3/20     21/3/2020  หญิง  36.0    Thailand
# 1467    1468       30/3/20     26/3/2020   ชาย  19.0    Thailand
# 1971    1972        3/4/20     31/3/2020  หญิง  70.0    Thailand
# 2638    2639       15/4/20     14/4/2020  หญิง  63.0    Thailand
# 2674    2675       17/4/20     16/4/2020   ชาย  68.0    Thailand
# 5949    5950      26/12/20    25/12/2020  หญิง  32.0    Thailand
# 6083    6084      27/12/20    26/12/2020  หญิง  36.0    Thailand
# 9334    9335        7/1/21      6/1/2021   ชาย  17.0    Thailand
# 9335    9336        7/1/21      6/1/2021   ชาย  20.0    Thailand
# 10611  10612       12/1/21     11/1/2021   ชาย  17.0    Thailand
# 11518  11519       16/1/21     15/1/2021   ชาย  12.0    Thailand
# 11698  11699       17/1/21     16/1/2021  หญิง  17.0    Thailand
# 11699  11700       17/1/21     16/1/2021  หญิง  37.0    Thailand
#
#       province_of_isolation province_of_onset district_of_onset  \
# 181                 ขอนแก่น           ขอนแก่น             เมือง
# 463                 ขอนแก่น           ขอนแก่น             เมือง
# 1467                ขอนแก่น           ขอนแก่น             เมือง
# 1971                ขอนแก่น           ขอนแก่น             เมือง
# 2638                ขอนแก่น           ขอนแก่น            น้ำพอง
# 2674                ขอนแก่น           ขอนแก่น            น้ำพอง
# 5949                ขอนแก่น           ขอนแก่น           แวงใหญ่
# 6083                ขอนแก่น           ขอนแก่น           แวงใหญ่
# 9334                ขอนแก่น           ขอนแก่น             เมือง
# 9335                ขอนแก่น           ขอนแก่น             เมือง
# 10611               ขอนแก่น           ขอนแก่น             เมือง
# 11518               ขอนแก่น           ขอนแก่น             เมือง
# 11698               ขอนแก่น           ขอนแก่น             เมือง
# 11699               ขอนแก่น           ขอนแก่น             เมือง
#
#                                                 risk
# 181                                          สนามมวย
# 463      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467                   คนไทยเดินทางกลับจากต่างประเทศ
# 1971   ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638                   สัมผัสผู้เดินทางจากต่างประเทศ
# 2674     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5949                               Cluster สมุทรสาคร
# 6083                               Cluster สมุทรสาคร
# 9334                            อยู่ระหว่างการสอบสวน
# 9335     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10611    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11518                           อยู่ระหว่างการสอบสวน
# 11698    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11699    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 0    1       12/1/20           NaN  หญิง  61.0       China
# 1    2       17/1/20           NaN  หญิง  74.0       China
# 2    3       22/1/20           NaN  หญิง  73.0    Thailand
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 4    5       24/1/20           NaN  หญิง  66.0       China
# 5    6       25/1/20           NaN  หญิง  33.0       China
# 6    7       26/1/20           NaN  หญิง  57.0       China
# 7    8       26/1/20           NaN  หญิง  73.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 0         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                นครปฐม            นครปฐม             เมือง
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4               นนทบุรี     กรุงเทพมหานคร               NaN
# 5         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 6         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 7       ประจวบคีรีขันธ์   ประจวบคีรีขันธ์            หัวหิน
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7  คนต่างชาติเดินทางมาจากต่างประเทศ

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ rows ที่ต้องการ
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 0    1       12/1/20           NaN  หญิง  61.0       China
# 2    3       22/1/20           NaN  หญิง  73.0    Thailand
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 5    6       25/1/20           NaN  หญิง  33.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 0         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 2                นครปฐม            นครปฐม             เมือง
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 5         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  คนต่างชาติเดินทางมาจากต่างประเทศ

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#    No. announce_date Notified date   sex   age nationality  \
# 0    1       12/1/20           NaN  หญิง  61.0       China
# 1    2       17/1/20           NaN  หญิง  74.0       China
# 3    4       22/1/20           NaN   ชาย  68.0       China
# 4    5       24/1/20           NaN  หญิง  66.0       China
# 5    6       25/1/20           NaN  หญิง  33.0       China
# 6    7       26/1/20           NaN  หญิง  57.0       China
#
#   province_of_isolation province_of_onset district_of_onset  \
# 0         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 1         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 3         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 4               นนทบุรี     กรุงเทพมหานคร               NaN
# 5         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
# 6         กรุงเทพมหานคร     กรุงเทพมหานคร               NaN
#
#                                risk
# 0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  คนต่างชาติเดินทางมาจากต่างประเทศ

# %% [markdown]
# HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %% [markdown]
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648   ชาย  42.0     กรุงเทพมหานคร
# 12649  หญิง  44.0            ชลบุรี
# 12650  หญิง  52.0             ระยอง
# 12651  หญิง  23.0             ระยอง
# 12652  หญิง  29.0             ระยอง
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12646    44.0
# 12649    44.0
# 12650    52.0
# 12651    23.0
# 12652    29.0
# Name: age, Length: 5917, dtype: float64

# %%
sum = 0
N = 0
for a in female['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.10576731191379

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data.shape #(12423, 3)
# Out:
# (12653, 3)

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (7315, 10)

# %%
this_data.dropna().shape
# Out:
# (9144, 3)

# %%
this_data.dropna()
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648   ชาย  42.0     กรุงเทพมหานคร
# 12649  หญิง  44.0            ชลบุรี
# 12650  หญิง  52.0             ระยอง
# 12651  หญิง  23.0             ระยอง
# 12652  หญิง  29.0             ระยอง
#
# [9144 rows x 3 columns]

# %%
this_data.dropna()
print(this_data.shape)
# Out:
# (12653, 3)

# %%
this_data.dropna(inplace=True)
# Out:
# /tmp/ipykernel_1153/3935554116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_data.dropna(inplace=True)

# %%
this_data.dropna(inplace=True)
print(this_data.shape)
# Out:
# (9144, 3)
# /tmp/ipykernel_1153/2129530393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_data.dropna(inplace=True)

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data.shape
# Out:
# (12653, 3)

# %%
this_data.dropna().shape
# Out:
# (9144, 3)

# %%
this_data.dropna(subset=['age']).shape
# Out:
# (9787, 3)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 11317

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated[this_data_updated['sex']=='ไม่รู้']
# Out:
#          sex  age province_of_onset
# 4397  ไม่รู้ -1.0         สมุทรสาคร
# 4398  ไม่รู้ -1.0         สมุทรสาคร
# 4399  ไม่รู้ -1.0         สมุทรสาคร
# 4400  ไม่รู้ -1.0         สมุทรสาคร
# 4401  ไม่รู้ -1.0         สมุทรสาคร
# ...      ...  ...               ...
# 7692  ไม่รู้ -1.0            ไม่รู้
# 7693  ไม่รู้ -1.0            ไม่รู้
# 7694  ไม่รู้ -1.0            ไม่รู้
# 8395  ไม่รู้ -1.0            ไม่รู้
# 8544  ไม่รู้ -1.0         สมุทรสาคร
#
# [1609 rows x 3 columns]

# %%
this_data_updated['province_of_onset']=='ไม่รู้'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[this_data_updated['province_of_onset']=='ไม่รู้']
# Out:
#          No. announce_date Notified date   sex   age nationality  \
# 415      416       22/3/20     22/3/2020   ชาย  29.0    Thailand
# 530      531       22/3/20     20/3/2020   ชาย  37.0    Thailand
# 556      557       22/3/20     21/3/2020  หญิง   6.0    Thailand
# 577      578       22/3/20     20/3/2020   ชาย   NaN    Thailand
# 589      590       22/3/20     21/3/2020   ชาย   NaN    Thailand
# ...      ...           ...           ...   ...   ...         ...
# 12406  12407       18/1/21     17/1/2021  หญิง  36.0       Burma
# 12407  12408       18/1/21     17/1/2021  หญิง  24.0       Burma
# 12408  12409       18/1/21     17/1/2021   ชาย  43.0       Burma
# 12409  12410       18/1/21     17/1/2021   ชาย  37.0       Burma
# 12410  12411       18/1/21     17/1/2021   ชาย  33.0       Burma
#
#       province_of_isolation province_of_onset district_of_onset  \
# 415           กรุงเทพมหานคร               NaN               NaN
# 530           กรุงเทพมหานคร               NaN               NaN
# 556           กรุงเทพมหานคร               NaN               NaN
# 577           กรุงเทพมหานคร               NaN               NaN
# 589           กรุงเทพมหานคร               NaN               NaN
# ...                     ...               ...               ...
# 12406             สมุทรสาคร               NaN               NaN
# 12407             สมุทรสาคร               NaN               NaN
# 12408             สมุทรสาคร               NaN               NaN
# 12409             สมุทรสาคร               NaN               NaN
# 12410             สมุทรสาคร               NaN               NaN
#
#                                               risk
# 415                                        สนามมวย
# 530    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 556                                        สนามมวย
# 577                                        สนามมวย
# 589                           อยู่ระหว่างการสอบสวน
# ...                                            ...
# 12406                            Cluster สมุทรสาคร
# 12407                            Cluster สมุทรสาคร
# 12408                            Cluster สมุทรสาคร
# 12409                            Cluster สมุทรสาคร
# 12410                            Cluster สมุทรสาคร
#
# [1336 rows x 10 columns]

# %%
this_data_updated_2 = this_data.fillna(value={'province_of_onset':'ไม่รู้'})

# %%
this_data_updated_2[this_data_updated['sex']=='ไม่รู้']
# Out:
#       sex  age province_of_onset
# 4397  NaN  NaN         สมุทรสาคร
# 4398  NaN  NaN         สมุทรสาคร
# 4399  NaN  NaN         สมุทรสาคร
# 4400  NaN  NaN         สมุทรสาคร
# 4401  NaN  NaN         สมุทรสาคร
# ...   ...  ...               ...
# 7692  NaN  NaN            ไม่รู้
# 7693  NaN  NaN            ไม่รู้
# 7694  NaN  NaN            ไม่รู้
# 8395  NaN  NaN            ไม่รู้
# 8544  NaN  NaN         สมุทรสาคร
#
# [1609 rows x 3 columns]

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    if (each_row[1]['age'] == 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)
# Out:
# (9335, sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 9335, dtype: object)

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] == 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 9335
# sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 9335, dtype: object

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, nationality, province_of_isolation, province_of_onset, district_of_onset, risk]
# Index: []

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  9787.000000
# mean    6327.000000    37.514969
# std     3652.750813    14.738641
# min        1.000000     1.000000
# 25%     3164.000000    27.000000
# 50%     6327.000000    35.000000
# 75%     9490.000000    47.000000
# max    12653.000000    97.000000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# np.float64(38.99581151832461)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  Notified date    sex    age  nationality  \
# 0      False          False           True  False  False        False
# 1      False          False           True  False  False        False
# 2      False          False           True  False  False        False
# 3      False          False           True  False  False        False
# 4      False          False           True  False  False        False
# ...      ...            ...            ...    ...    ...          ...
# 12648  False          False          False  False  False        False
# 12649  False          False          False  False  False        False
# 12650  False          False          False  False  False        False
# 12651  False          False          False  False  False        False
# 12652  False          False          False  False  False        False
#
#        province_of_isolation  province_of_onset  district_of_onset   risk
# 0                      False              False               True  False
# 1                      False              False               True  False
# 2                      False              False              False  False
# 3                      False              False               True  False
# 4                      False              False               True  False
# ...                      ...                ...                ...    ...
# 12648                  False              False              False  False
# 12649                  False              False              False  False
# 12650                  False              False              False  False
# 12651                  False              False              False  False
# 12652                  False              False              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
