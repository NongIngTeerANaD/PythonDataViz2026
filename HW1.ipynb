# %% [markdown]
# <a href="https://colab.research.google.com/github/NongIngTeerANaD/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  ธีรนาฏ ขอร่ม

# %%
print('663020261-2')
# Out:
# 663020261-2
